# %% [markdown]
# <a href="https://www.kaggle.com/code/mehmetseviker/baslangic?scriptVersionId=194898837" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# **Verilen string ifadenin tüm harflerini büyük harfe çevirme. Virgül ve nokta yerine space koymak,**

# %%
text = "The goal is to turn data into information, and information into insight."
text.upper()

# %%
text = "The goal is to turn data into information, and information into insight."
text.replace(".", " ")

text.upper().replace(","," ").replace("."," ").split()

# %%
text.split()

# %% [markdown]
# **Verilen liste üzerinden ["D", "A", "T", "A"] listesi oluşturunuz.**

# %%
lst = ["D","A","T","A","S","C","I","E","N","C","E"]
yeni_lst = [l for i, l in enumerate(lst) if i <4 ]
yeni_lst

#Yada
lst[0:4] #slicing metodu

# %% [markdown]
# **Sekizinci indeksteki elemanı siliniz**

# %%
lst = ["D","A","T","A","S","C","I","E","N","C","E"]
lst.pop(8)
lst

# %% [markdown]
# **Yeni bir eleman ekleyiniz.**

# %%
lst = ["D","A","T","A","S","C","I","E","N","C","E"]
lst.append(5)
lst

# %% [markdown]
# **Sekizinci indekse "N" elemanını tekrar ekleyiniz**

# %%
lst = ["D","A","T","A","S","C","I","E","N","C","E"]
lst.insert(8, "N")
lst

# %% [markdown]
# **Verilen sözlük yapısına aşağıdaki adımları uygulayınız
# dict = {'Christian': ["America",18], 'Daisy':["England",12], 'Antonio':["Spain",22], 'Dante':["Italy",25]}**

# %%
dict = {'Christian': ["America",18],
        'Daisy':["England",12],
        'Antonio':["Spain",22],
        'Dante':["Italy",25]}

#Key değerlerine erişiniz.
dict.keys()

#Value'lara erişiniz.
dict.values()

#Daisy key'ine ait 12 değerini 13 olarak güncelleyiniz.
dict["Daisy"][1] = 13
dict.items()

#: Key değeri Ahmet value değeri [Turkey,24] olan yeni bir değer ekleyiniz.
dict.update({"Ahmet": ["Turkey", 24]})
dict.items()

#Antonio'yu dictionary'den siliniz.
del dict["Antonio"]
dict.items()

#Yada

dict.pop("Antonio")

# %% [markdown]
# **Görev5: Argüman olarak bir liste alan, listenin içerisindeki tek ve çift sayıları ayrı listelere atayan ve bu listeleri
# return eden fonksiyon yazınız.**

# %%
l = [2,13,18,93,22]

tek = []
cift = []
def tekcift(list):
    for i in l:
        if i % 2 == 0:
            cift.append(i)
        else:
            tek.append(i)
    return (tek, cift)

tekcift(l)
print(cift, tek)

# %% [markdown]
# **GÖREV 6: Aşağıda verilen listede mühendislik ve tıp fakülterinde dereceye giren öğrencilerin isimleri bulunmaktadır.
# - Sırasıyla ilk üç öğrenci mühendislik fakültesinin başarı sırasını temsil ederken son üç öğrenci de tıp fakültesi öğrenci sırasına aittir.
# - Enumarate kullanarak öğrenci derecelerini fakülte özelinde yazdırınız.**

# %%
ogrenciler = ["Ali","Veli","Ayşe","Talat","Zeynep","Ece"]

for index, ogrenci in enumerate(ogrenciler, 1):
    if index < 4:
        print("Mühendislik Fakültesi", index, ". ögrenci", ogrenci)
    else:
        print("Tıp Fakültesi", (index-3), ". ögrenci", ogrenci)

#Yada
        
if index<=2:

        print("Mühendislik Fakültesi " + str(index+1) + ". öğrenci:" + ogr)
      
    else:
        print("Tıp Fakültesi " + str(index-2) + ". öğrenci:" + ogr)

# %% [markdown]
# **GÖREV 7: Aşağıda 3 adet liste verilmiştir. Listelerde sırası ile bir dersin kodu, kredisi ve kontenjan bilgileri yer almaktadır. Zip kullanarak ders bilgilerini bastırınız.**

# %%
ders_kodu = ["CMP1005","PSY1001","HUK1005","SEN2204"]
kredi = [3,4,2,4]
kontenjan = [30,75,150,25]

tam = list(zip(kredi, ders_kodu, kontenjan))

for i, j, k in tam:
    print("Kredisi {} olan {} kodlu dersin kontenjanı {} kişidir.".format(i, j, k))

#for k, kod, kon in zip(kredi, ders_kodu, kontenjan):
#print("kredi" {k} olan {kod} kodlu dersin kontenjanı {kon} kişidir)

# %% [markdown]
# **GÖREV 8: Aşağıda 2 adet set verilmiştir.
# Sizden istenilen eğer 1. küme 2. kümeyi kapsiyor ise ortak elemanlarını eğer kapsamıyor ise 2. kümenin 1. kümeden farkını yazdıracak fonksiyonu tanımlamanız beklenmektedir.**

# %%
kume1 = set(["data", "python"])
kume2 = set(["data", "function", "qcut", "lambda", "python", "miuul"])

def kumeler(kume1, kume2):
    if kume1.issuperset(kume2):
        print(kume1.intersection(kume2))
    else:
        print(kume2.difference(kume1))

kumeler(kume1, kume2)

# %% [markdown]
# # # # # **List Comprehensions**

# %% [markdown]
# **GÖREV 1: List Comprehension yapısı kullanarak car_crashes verisindeki numeric değişkenlerin isimlerini büyük harfe çeviriniz ve başına NUM ekleyiniz.**

# %% [markdown]
# **Numerik olmayanların da isimleri büyümeli.
# Tek bir list comp yapısı ile yapılmalı.**

# %%
import seaborn as sns
import pandas as pd

df = sns.load_dataset("car_crashes")

["NUM_" + col.upper() if df[col].dtypes in ["int64", "float64"] else col.upper() for col in df.columns]

#Yada

["NUM_" + col.upper() if df[col].dtypes in [int, float] else col.upper() for col in df.columns]

# %% [markdown]
# **GÖREV 2: List Comprehension yapısı kullanarak car_crashes verisindeki isminde "no" barındırmayan değişkenlerin isimlerininin sonuna "FLAG" yazınız.**

# %% [markdown]
# **Tüm değişken isimleri büyük olmalı.
# Tek bir list comp ile yapılmalı.**

# %%
[col.upper() + "_FLAG" if "no" not in col else col.upper() for col in df.columns]

# %% [markdown]
# **Görev 3: List Comprehension yapısı kullanarak aşağıda verilen değişken isimlerinden FARKLI olan değişkenlerin isimlerini seçiniz ve yeni bir dataframe oluşturunuz.
# Önce yukarıdaki listeye göre list comprehension kullanarak new_cols adında yeni liste oluşturunuz.
# Sonra df[new_cols] ile bu değişkenleri seçerek yeni bir df oluşturunuz adını new_df olarak isimlendiriniz.**

# %%
og_list = ["abbrev", "no_previous"]

new_col = [col for col in df.columns if col not in og_list]

new_df = df[new_col]

new_df.head()

# %% [markdown]
# # Pandas Alıştırmalar

# %%
import numpy as np
import seaborn as sns
import pandas as pd

# %% [markdown]
# **Görev 1: Seaborn kütüphanesi içerisinden Titanic veri setini tanımlayınız.**

# %%
df = sns.load_dataset("titanic")

# %% [markdown]
# **Görev 2: Yukarıda tanımlanan Titanic veri setindeki kadın ve erkek yolcuların sayısını bulunuz.**

# %%
df["sex"].value_counts()

# %% [markdown]
# **Görev 3: Her bir sutuna ait unique değerlerin sayısını bulunuz.**

# %%
df.nunique()

# %% [markdown]
# **Görev 4: pclass değişkeninin unique değerleri bulunuz**

# %%
df["pclass"].nunique()

# %% [markdown]
# **Görev 5:  pclass ve parch değişkenlerinin unique değerlerinin sayısını bulunuz.**

# %%
col_names = ["pclass", "parch"]
df[col_names].nunique()

#yada

df[["pclass", "parch"]].nunique()

# %% [markdown]
# **Görev 6: embarked değişkeninin tipini kontrol ediniz. Tipini category olarak değiştiriniz. Tekrar tipini kontrol ediniz.**

# %%
df.embarked.dtype

#Yada

df["embarked"].dtype

df.embarked.astype('category')

# %% [markdown]
# **Görev 7: embarked değeri C olanların tüm bilgelerini gösteriniz.**

# %%
df[df["embarked"] == "C"].head()
df[df["embarked"] == "C"].info()
df[df["embarked"] == "C"].count()
df[df["embarked"] == "C"].describe().T

# %% [markdown]
# **Görev 8: embarked değeri S olmayanların tüm bilgelerini gösteriniz.**

# %%
df[df["embarked"] != "S"].head()
df[df["embarked"] != "S"].info()
df[df["embarked"] != "S"].count()
df[df["embarked"] != "S"].describe().T

# %% [markdown]
# **Görev 9: Yaşı 30 dan küçük ve kadın olan yolcuların tüm bilgilerini gösteriniz.**

# %%
df.loc[(df["age"] < 30) & (df["sex"] == "female"), :].head()
df.loc[(df["age"] < 30) & (df["sex"] == "female"), :].describe().T

# %% [markdown]
# **Görev 10: Fare'i 500'den büyük veya yaşı 70 den büyük yolcuların bilgilerini gösteriniz.**

# %%
df.loc[(df.fare > 500) & (df.age > 70), :].head() #--> Empty DataFrame
df.loc[(df.fare > 500) & (df.age > 70), :].count() #--> bütün değerler 0
df[df.fare > 500][df.age > 70].values.any() #--> False
#Bu şartı sağlayan yolcu yok

# %% [markdown]
# **Görev 11: Her bir değişkendeki boş değerlerin toplamını bulunuz.**

# %%
df.isnull().sum()

# %% [markdown]
# **Görev 12: who değişkenini dataframe'den düşürün.**

# %%
df.drop("who", axis=1)

# %% [markdown]
# **Görev 13: deck değikenindeki boş değerleri deck değişkenin en çok tekrar eden değeri (mode) ile doldurunuz.**

# %%
df["deck"].fillna(df.deck.mode()) #--> C

df["deck"].fillna(value = "C", inplace = True)
df.deck.isnull().sum()

#Yada
df["deck"] = df["deck"].fillna(df["deck"].mode()) #Tip karakter olunca yöntem çalışmıyor ama aşağıdaki sorudaki gibi int olunca çalışıyor neden?

# %% [markdown]
# **Görev 14: age değikenindeki boş değerleri age değişkenin medyanı ile doldurun.**

# %%
df["age"] = df["age"].fillna(df["age"].median())

# %% [markdown]
# **Görev 15: survived değişkeninin Pclass ve Cinsiyet değişkenleri kırılımınında sum, count, mean değerlerini bulunuz.**

# %%
df.groupby(["pclass", "sex"]).agg({"survived": ["sum", "count", "mean"]})

# %% [markdown]
# **Görev 16:  30 yaşın altında olanlar 1, 30'a eşit ve üstünde olanlara 0 vericek bir fonksiyon yazınız.
# Yazdığınız fonksiyonu kullanarak titanik veri setinde age_flag adında bir değişken oluşturunuz oluşturunuz. (apply ve lambda yapılarını kullanınız)**

# %%
df["new_flag"] = pd.cut(df["age"], [0, 30, 80])

#yada

def ayristirma(x):
    if x < 30:
        a = 1
    else:
        a = 0
    return a

new_flag = df.loc[:, "age"].apply(lambda x: ayristirma(x))

df["new_flag"] = new_flag

#Yada:

df["new_flag"] = df["age"]

def ayristirma(column):
    for index, value in enumerate(column):
        if value < 30:
            df.new_flag[index] = 1
        else:
            df.new_flag[index] = 0
    return df.new_flag

ayristirma(df.age) #Hata mesajı veriyor ama çalışıyor.

# %% [markdown]
# **Görev 17: Seaborn kütüphanesi içerisinden Tips veri setini tanımlayınız.**

# %%
df = sns.load_dataset("tips")

# %% [markdown]
# **Görev 18: Time değişkeninin kategorilerine (Dinner, Lunch) göre total_bill değerlerinin toplamını, min, max ve ortalamasını bulunuz.**

# %%
df.time.value_counts()

#Dinner    176
#Lunch      68

df.groupby("time").agg({"total_bill": ["sum", "min", "max", "mean"]})

#       total_bill                    
#              sum   min    max   mean
#time                                 
#Lunch    1167.470 7.510 43.110 17.169
#Dinner   3660.300 3.070 50.810 20.797

# %% [markdown]
# **Görev 19: Günlere ve time göre total_bill değerlerinin toplamını, min, max ve ortalamasını bulunuz.**

# %%
df.groupby(["time", "day"]).agg({"total_bill": ["sum", "min", "max", "mean"]})

#            total_bill                     
#                   sum    min    max   mean
#time   day                                 
#Lunch  Thur   1077.550  7.510 43.110 17.665
#       Fri      89.920  8.580 16.270 12.846
#       Sat       0.000    NaN    NaN    NaN
#       Sun       0.000    NaN    NaN    NaN
#Dinner Thur     18.780 18.780 18.780 18.780
#       Fri     235.960  5.750 40.170 19.663
#       Sat    1778.400  3.070 50.810 20.441
#       Sun    1627.160  7.250 48.170 21.410

# %% [markdown]
# **Görev 20: Lunch zamanına ve kadın müşterilere ait total_bill ve tip değerlerinin day'e göre toplamını, min, max ve ortalamasını bulunuz.**

# %%
df.loc[(df.sex == "Female") & (df.time == "Lunch")].groupby("day").agg({"total_bill": ["sum", "min", "max", "mean"], "tip": ["sum", "min", "max", "mean"]})

# %% [markdown]
# **Görev 21: size'i 3'ten küçük, total_bill'i 10'dan büyük olan siparişlerin ortalaması nedir? (loc kullanınız)**

# %%
columns = df.columns
df.loc[(df["size"] < 3) & (df["total_bill"] > 10), columns].total_bill

#Yada;
#UserWarning: Boolean Series key will be reindexed to match DataFrame index. Hatası verir ama çalışır.
df[df["size"] < 3][df["total_bill"] > 10].total_bill.mean()

# %% [markdown]
# **Görev 22: total_bill_tip_sum adında yeni bir değişken oluşturunuz. Her bir müşterinin ödediği totalbill ve tip in toplamını versin.**

# %%
df["total_bill_tip_sum"] = df.total_bill + df.tip

# %% [markdown]
# **Görev 23: total_bill_tip_sum değişkenine göre büyükten küçüğe sıralayınız ve ilk 30 kişiyi yeni bir dataframe'e atayınız.**

# %%
ilk_otuz = pd.DataFrame()
ilk_otuz = (df.sort_values(by='total_bill_tip_sum', ascending=False)).head(30)

# %% [markdown]
# # **Kural Tabanlı Sınıflandırma ile Potansiyel Müşteri Getirisi Hesaplama**

# %% [markdown]
# **Kural Tabanlı Sınıflandırma**
#
# ![image.png](attachment:1a1a03b5-4c04-489c-935a-44c59de63330.png)

# %% [markdown]
# # **Proje Görevleri1**

# %% [markdown]
# ****Soru 1: persona.csvdosyasını okutunuz ve veri seti ile ilgili genel bilgileri gösteriniz.****

# %%
import numpy as np
import seaborn as sns
import pandas as pd

df = pd.read_csv("/kaggle/input/personacsv/persona.csv")

df.head()
df.info()
df.describe()
df.shape
df.isnull().count()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5000 entries, 0 to 4999
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   PRICE    5000 non-null   int64
#  1   SOURCE   5000 non-null   object
#  2   SEX      5000 non-null   object
#  3   COUNTRY  5000 non-null   object
#  4   AGE      5000 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 234.4+ KB
# PRICE      5000
# SOURCE     5000
# SEX        5000
# COUNTRY    5000
# AGE        5000
# dtype: int64

# %% [markdown]
# **Soru 2: Kaç uniqueSOURCE vardır? Frekansları nedir?**

# %%
df.SOURCE.nunique()
df.SOURCE.value_counts()
# Out:
# SOURCE
# android    2974
# ios        2026
# Name: count, dtype: int64

# %% [markdown]
# **Soru 3:Kaç uniquePRICE vardır?**

# %%
df.PRICE.nunique()
# Out:
# 6

# %% [markdown]
# **Soru 4:Hangi PRICE'dan kaçar tane satış gerçekleşmiş?**

# %%
df.PRICE.value_counts()
# Out:
# PRICE
# 29    1305
# 39    1260
# 49    1031
# 19     992
# 59     212
# 9      200
# Name: count, dtype: int64

# %% [markdown]
# **Soru 5:Hangi ülkeden kaçar tane satış olmuş?**

# %%
df.COUNTRY.value_counts()
# Out:
# COUNTRY
# usa    2065
# bra    1496
# deu     455
# tur     451
# fra     303
# can     230
# Name: count, dtype: int64

# %% [markdown]
# **Soru 6:Ülkelere göre satışlardan toplam ne kadar kazanılmış?**

# %%
df.groupby("COUNTRY")["PRICE"].sum()
# Out:
# COUNTRY
# bra    51354
# can     7730
# deu    15485
# fra    10177
# tur    15689
# usa    70225
# Name: PRICE, dtype: int64

# %% [markdown]
# **Soru 7:SOURCE türlerine göre satış sayıları nedir?**

# %%
df.groupby("SOURCE").agg({"PRICE": "count"})

#Yada

df.groupby("SOURCE")["PRICE"].count()
# Out:
# SOURCE
# android    2974
# ios        2026
# Name: PRICE, dtype: int64

# %% [markdown]
# **Soru 8:Ülkelere göre PRICE ortalamaları nedir?**

# %%
df.groupby("COUNTRY").agg({"PRICE": "mean"})
# Out:
#              PRICE
# COUNTRY
# bra      34.327540
# can      33.608696
# deu      34.032967
# fra      33.587459
# tur      34.787140
# usa      34.007264

# %% [markdown]
# **Soru 9:SOURCE'lara göre PRICE ortalamaları nedir?**

# %%
df.groupby("SOURCE").agg({"PRICE": "mean"})

#Yada

df.groupby("SOURCE")["PRICE"].mean()
# Out:
# SOURCE
# android    34.174849
# ios        34.069102
# Name: PRICE, dtype: float64

# %% [markdown]
# **Soru 10: COUNTRY-SOURCE kırılımındaPRICE ortalamaları nedir?**

# %%
df.groupby(["COUNTRY", "SOURCE"])["PRICE"].mean()

#Yada

df.groupby(["COUNTRY", "SOURCE"]).agg({"PRICE": "mean"})

df.groupby(by = ["COUNTRY", "SOURCE"]).agg({"PRICE": "mean"}) # groupby içerisinde tekrar by kullanılabilir.
# Out:
#                      PRICE
# COUNTRY SOURCE
# bra     android  34.387029
#         ios      34.222222
# can     android  33.330709
#         ios      33.951456
# deu     android  33.869888
#         ios      34.268817
# fra     android  34.312500
#         ios      32.776224
# tur     android  36.229437
#         ios      33.272727
# usa     android  33.760357
#         ios      34.371703

# %% [markdown]
# # **Proje Görevleri2**
# **COUNTRY, SOURCE, SEX, AGE kırılımındaortalama kazançlar nedir?**
#
#
# ![image.png](attachment:e0d929fd-25ec-4d65-9138-19b734175f25.png)

# %%
df.groupby(["COUNTRY", "SOURCE", "SEX", "AGE"])["PRICE"].mean()

#Yada
df.groupby(by = ["COUNTRY", "SOURCE", "SEX", "AGE"]).agg({"PRICE": "mean"})
# Out:
#                                 PRICE
# COUNTRY SOURCE  SEX    AGE
# bra     android female 15   38.714286
#                        16   35.944444
#                        17   35.666667
#                        18   32.255814
#                        19   35.206897
# ...                               ...
# usa     ios     male   42   30.250000
#                        50   39.000000
#                        53   34.000000
#                        55   29.000000
#                        59   46.500000
#
# [348 rows x 1 columns]

# %% [markdown]
# # **Görev 3:  Çıktıyı PRICE’a göre sıralayınız**
#
# * **Önceki sorudaki çıktıyı daha iyi görebilmek için sort_values metodunu azalan olacak şekilde PRICE’a göre uygulayınız.**
# * **Çıktıyı agg_df olarak kaydediniz.**
#
# ![image.png](attachment:ffdeb386-79ee-41db-81e5-543136f6e644.png)

# %%
#df.sort_values(by='PRICE', ascending=False) sort_values daki Price önündeki by kullanıldığında enalttaki code hata veriyor by ile ilgili, 
#onu kaldırınca çalışıyor.

agg_df0 = df.groupby(by=["COUNTRY", 'SOURCE', "SEX", "AGE"]).agg({"PRICE": "mean"})

agg_df = agg_df0.sort_values("PRICE", ascending=False)
agg_df.head()
# Out:
#                             PRICE
# COUNTRY SOURCE  SEX    AGE
# bra     android male   46    59.0
# usa     android male   36    59.0
# fra     android female 24    59.0
# usa     ios     male   32    54.0
# deu     android female 36    49.0

# %% [markdown]
# # **Görev 4:  Indekste yer alan isimleri değişken ismine çeviriniz.**
# **Üçüncü sorunun çıktısında yer alan PRICE dışındaki tüm değişkenler index isimleridir. Bu isimleri değişken isimlerine çeviriniz**
#
# ![image.png](attachment:dfdac998-5b16-49da-981a-289a6bbb64a0.png)

# %%
agg_df = agg_df.reset_index()
agg_df.head()
# Out:
#   COUNTRY   SOURCE     SEX  AGE  PRICE
# 0     bra  android    male   46   59.0
# 1     usa  android    male   36   59.0
# 2     fra  android  female   24   59.0
# 3     usa      ios    male   32   54.0
# 4     deu  android  female   36   49.0

# %% [markdown]
# # **Görev 5:  Age değişkenini kategorik değişkene çeviriniz ve agg_df’e ekleyiniz**
# * **Age sayısal değişkenini kategorik değişkene çeviriniz.**
# * **Aralıkları ikna edici şekilde oluşturunuz.**
# * **Örneğin: ‘0_18', ‘19_23', '24_30', '31_40', '41_70'****
#
# ![image.png](attachment:41585ff0-b465-4d9f-abce-854af7ebfac8.png)

# %%
agg_df["AGE_CAT"] = pd.cut(agg_df["AGE"], [0, 18, 23, 31, 40, 70], labels = ["0_18", "19_23", "24_30", "31_40", "41_70"])
agg_df.head()
# Out:
#   COUNTRY   SOURCE     SEX  AGE  PRICE AGE_CAT
# 0     bra  android    male   46   59.0   41_70
# 1     usa  android    male   36   59.0   31_40
# 2     fra  android  female   24   59.0   24_30
# 3     usa      ios    male   32   54.0   31_40
# 4     deu  android  female   36   49.0   31_40

# %% [markdown]
# # **Görev 6:  Yeni seviye tabanlı müşterileri (persona) tanımlayınız.**
# * **Yeni seviye tabanlı müşterileri (persona) tanımlayınız ve veri setine değişken olarak ekleyiniz.**
# * **Yeni eklenecek değişkenin adı: customers_level_based**
# * **Önceki soruda elde edeceğiniz çıktıdaki gözlemleri bir araya getirerek customers_level_based değişkenini oluşturmanız gerekmektedir.**
#
# ![image.png](attachment:7040cedc-a8b0-458c-9a11-fbf5c3f27b68.png)

# %%
agg_df["AGE_CAT"] = agg_df["AGE_CAT"].astype("O") #Önce AGE_CAT değişkeninin type ını kategoriden objeye çevirdik, aksi taktirde hata veriyor.

agg_df["CUSTOMERS_LEVEL_BASED"] = agg_df.COUNTRY + "_" + agg_df.SOURCE + "_" + agg_df.SEX + "_" + agg_df.AGE_CAT
agg_df.info()
agg_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 348 entries, 0 to 347
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   COUNTRY                348 non-null    object
#  1   SOURCE                 348 non-null    object
#  2   SEX                    348 non-null    object
#  3   AGE                    348 non-null    int64
#  4   PRICE                  348 non-null    float64
#  5   AGE_CAT                348 non-null    object
#  6   CUSTOMERS_LEVEL_BASED  348 non-null    object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 19.2+ KB
#   COUNTRY   SOURCE     SEX  AGE  PRICE AGE_CAT     CUSTOMERS_LEVEL_BASED
# 0     bra  android    male   46   59.0   41_70    bra_android_male_41_70
# 1     usa  android    male   36   59.0   31_40    usa_android_male_31_40
# 2     fra  android  female   24   59.0   24_30  fra_android_female_24_30
# ...

# %%
agg_df = agg_df[["CUSTOMERS_LEVEL_BASED", "PRICE"]]
agg_df.head()
# Out:
#       CUSTOMERS_LEVEL_BASED  PRICE
# 0    bra_android_male_41_70   59.0
# 1    usa_android_male_31_40   59.0
# 2  fra_android_female_24_30   59.0
# 3        usa_ios_male_31_40   54.0
# 4  deu_android_female_31_40   49.0

# %%
agg_df = agg_df.groupby("CUSTOMERS_LEVEL_BASED")["PRICE"].mean()
agg_df.head()
# Out:
# CUSTOMERS_LEVEL_BASED
# bra_android_female_0_18     35.645303
# bra_android_female_19_23    34.077340
# bra_android_female_24_30    34.018148
# bra_android_female_31_40    34.858480
# bra_android_female_41_70    36.737179
# Name: PRICE, dtype: float64

# %%
agg_df = agg_df.reset_index()
agg_df.head()
# Out:
#       CUSTOMERS_LEVEL_BASED      PRICE
# 0   bra_android_female_0_18  35.645303
# 1  bra_android_female_19_23  34.077340
# 2  bra_android_female_24_30  34.018148
# 3  bra_android_female_31_40  34.858480
# 4  bra_android_female_41_70  36.737179

# %% [markdown]
# # **Görev 7:  Yeni müşterileri (personaları) segmentlere ayırınız.**
# * **Yeni müşterileri (Örnek: USA_ANDROID_MALE_0_18) PRICE’agöre 4 segmente ayırınız.**
# * **Segmentleri SEGMENT isimlendirmesi ile değişken olarak agg_df’e ekleyiniz.**
# * **Segmentleri betimleyiniz (Segmentlere göre groupby yapıp price mean, max, sum’larını alınız)**
#
# ![image.png](attachment:f54c2dea-7d10-44e7-ba9b-27a482566e5c.png)

# %%
agg_df["SEGMENT"] = pd.qcut(agg_df["PRICE"], 4, labels = ["D","C" ,"B" ,"A" ])

# %%
agg_df.head()
# Out:
#       CUSTOMERS_LEVEL_BASED      PRICE SEGMENT
# 0   bra_android_female_0_18  35.645303       B
# 1  bra_android_female_19_23  34.077340       C
# 2  bra_android_female_24_30  34.018148       C
# 3  bra_android_female_31_40  34.858480       B
# 4  bra_android_female_41_70  36.737179       A

# %%
agg_df.groupby("SEGMENT").agg({"PRICE": ["mean", "max", "sum"]})
# Out:
# /tmp/ipykernel_36/64560030.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg_df.groupby("SEGMENT").agg({"PRICE": ["mean", "max", "sum"]})
#              PRICE
#               mean        max          sum
# SEGMENT
# D        29.190382  32.239954   817.330703
# C        33.483324  34.103727   904.049745
# B        35.058696  36.060606   946.584791
# A        38.762537  45.428571  1046.588497

# %% [markdown]
# # **Görev 8:  Yeni gelen müşterileri sınıflandırıp, ne kadar gelir getirebileceklerini  tahmin ediniz**
# * **33 yaşında ANDROID kullanan bir Türk kadını hangi segmenteaittir ve ortalama ne kadar gelir kazandırması beklenir?**
# * **35 yaşında IOS kullanan bir Fransız kadını hangi segmenteaittir ve ortalama ne kadar gelir kazandırması beklenir?**
#
# ![image.png](attachment:8cf2ff25-8fc5-4193-ac3d-26dde6e4d611.png)

# %%
agg_df[agg_df["CUSTOMERS_LEVEL_BASED"] == "tur_android_female_31_40"]
# Out:
#        CUSTOMERS_LEVEL_BASED  PRICE SEGMENT
# 72  tur_android_female_31_40   43.0       A

# %%
agg_df[agg_df["CUSTOMERS_LEVEL_BASED"] == "fra_ios_female_31_40"]
# Out:
#    CUSTOMERS_LEVEL_BASED  PRICE SEGMENT
# 63  fra_ios_female_31_40   33.0       C
